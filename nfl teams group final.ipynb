# %%
import pandas as pd
df = pd.read_csv('nfl_fans.csv')

# %%
df.head()
# Out:
#    Unnamed: 0           Democrat        Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0         NaN               Team  Tot. Respondents      Asian      Black
# 1         NaN  Arizona Cardinals               148          2          7
# 2         NaN    Atlanta Falcons               188          3         27
# 3         NaN   Baltimore Ravens               150          5         14
# 4         NaN      Buffalo Bills                92          2          3
#
#   Unnamed: 5 Unnamed: 6 Independent Unnamed: 8 Unnamed: 9     ...      \
# 0   Hispanic      Other       White      Total      Asian     ...
# 1          7          3          20         39          4     ...
# 2          5          1          23         59          3     ...
# 3          3          4          30         56          3     ...
# 4          1          1          15         22          7     ...
#
#   Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20 Unnamed: 21  \
# ...
